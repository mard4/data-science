# %% [markdown]
# ## The dataset
#
# -  1547 real patient cases on low back pain
# - Outcome variable: Treatment 1-5
#
# #### Research question
# 1. To what extend can one, based on the answers given in the questionnaire, automatically determine the
# advised treatment for a patient with back pain.
# 2. To what extend can one reduce the number of questions, i.e. which questions can be left out without
# major decrease in performance? <br>
# Evaluate techniques beyond Decision Trees and Regression.
#
# <h2 style="size:20px;">Input Variables</h2>
# <table style="width: 100%;
#             border-collapse: collapse;">
#     <tr>
#         <th>Variable</th>
#         <th>Description</th>
#     </tr>
#     <tr>
#         <td>Fever</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Duration_in_years</td>
#         <td>
#             1 = 0-1 weeks <br>
#             2 = 1-2 weeks <br>
#             3 = 3-4 weeks <br>
#             4 = 4-5 weeks <br>
#             5 = 6-8 weeks <br>
#             6 = 9-11 weeks <br>
#             7 = 3-6 months <br>
#             8 = 6-9 months <br>
#             9 = 9-12 months <br>
#             10 = more than 1 year
#         </td>
#     </tr>
#     <tr>
#         <td>Sick_leave</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Earlier_hospitalization</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Workoverload</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Familiy_history</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Depression</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Extremely_nervous</td>
#         <td>Value between 0 (not at all) and 10 (Very tense or anxious)</td>
#     </tr>
#     <tr>
#         <td>Stress</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Relationship_with_colleagues</td>
#         <td>Value between 0 (not satisfied at all) and 10 (completely satisfied)</td>
#     </tr>
#     <tr>
#         <td>Irrational_thoughts_risk_lasting</td>
#         <td>Value between 0 (no risk) and 10 (Very high risk)</td>
#     </tr>
#     <tr>
#         <td>Irrational_thoughts_work</td>
#         <td>Value between 0 (fully disagree) and 10 (fully agree)</td>
#     </tr>
#     <tr>
#         <td>Coping_strategy</td>
#         <td>Value between 0 (not at all) and 10 (Can reduce the pain completely)</td>
#     </tr>
#     <tr>
#         <td>Kinesiophobia_physical_exercise</td>
#         <td>Value between 0 (fully disagree) and 10 (fully agree)</td>
#     </tr>
#     <tr>
#         <td>Kinesiophobia_pain_stop</td>
#         <td>Value between 0 (fully disagree) and 10 (fully agree)</td>
#     </tr>
#     <tr>
#         <td>Age</td>
#         <td>0-19, 20-29, ….., >=80</td>
#     </tr>
#     <tr>
#         <td>Uses_analgesics</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Uses_corticosteroids</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Serious_disease</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Neurogenic_signals</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Continuous_pain</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Decreased_mobility</td>
#         <td>Value</td>
#     </tr>
#     <tr>
#         <td>Nocturnal_pain</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Weightloss_per_year</td>
#         <td>1=decrease, 2=increase, 3=stable, 4=fluctuating</td>
#     </tr>
#     <tr>
#         <td>Loss_muscle_strength</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Trauma</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Failure_symptoms</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Incoordination</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Neck_pain_intensity</td>
#         <td>Value between 0 (None) and 10 (Unbearable)</td>
#     </tr>
#     <tr>
#         <td>Low_back_pain_intensity</td>
#         <td>Value between 0 (None) and 10 (Unbearable)</td>
#     </tr>
#     <tr>
#         <td>Arm_left_pain_intensity</td>
#         <td>Value between 0 (None) and 10 (Unbearable)</td>
#     </tr>
#     <tr>
#         <td>Arm_right_pain_intensity</td>
#         <td>Value between 0 (None) and 10 (Unbearable)</td>
#     </tr>
#     <tr>
#         <td>Leg_left_pain_intensity</td>
#         <td>Value between 0 (None) and 10 (Unbearable)</td>
#     </tr>
#     <tr>
#         <td>Leg_right_pain_intensity</td>
#         <td>Value between 0 (None) and 10 (Unbearable)</td>
#     </tr>
#     <tr>
#         <td>Working_ability</td>
#         <td>Value between 0 and 10</td>
#     </tr>
#     <tr>
#         <td>Paid_work</td>
#         <td>1=yes, 0=no</td>
#     </tr>
# </table>
#
# <h2>Outcome Variable</h2>
# <table>
#     <tr>
#         <th>Variable</th>
#         <th>Description</th>
#     </tr>
#     <tr>
#         <td>Treatment</td>
#         <td>
#             1. Advice <br>
#             2. Rehabilitation <br>
#             3. Surgery <br>
#             4. Injection/medication <br>
#             5. Combination of 1-4
#         </td>
#     </tr>
# </table>

# %% [markdown]
# To use the database, connect to bronto.ewi.utwente.nl using these credentials:
#
# - Example command for connecting:
# psql -h bronto.ewi.utwente.nl -U dab_ds2425-2a_10 dab_ds2425-2a_10
#
# - https://bronto.ewi.utwente.nl/phppgadmin/

# %%
import pandas as pd
from connection import *

print("Columns in dataset")
data = pd.read_excel("./data/Dataset - LBP RA.xlsx", sheet_name='Training Dataset')
print(data.columns)
##print(training_dataset.head())

# Create the Patient ID column
data.insert(0, 'Patient_ID', data.index)

data.head(10)
# %matplotlib inline
# Out:
# Columns in dataset
# Index(['Treatment', 'Fever', 'Duration_of_pain', 'Sick_leave',
#        'Earlier_hospitalization', 'Workoverload', 'Familiy_history',
#        'Depression', 'Extremely_nervous', 'Stress',
#        'Relationship_with_colleagues', 'Irrational_thoughts_risk_lasting',
#        'Irrational_thoughts_work', 'Coping_strategy',
#        'Kinesiophobia_physical_exercise', 'Kinesiophobia_pain_stop', 'Age',
#        'Uses_analgesics', 'Uses_corticosteroids', 'Serious_disease',
#        'Neurogenic_signals', 'Continuous_pain', 'Decreased_mobility',
#        'Nocturnal_pain', 'Weightloss_per_year', 'Loss_muscle_strength',
#        'Trauma', 'Failure_symptoms', 'Incoordination', 'neck_pain_intensity',
#        'low_back_pain_intensity', 'arm_left_pain_intensity',
#        'arm_right_pain_intensity', 'leg_left_pain_intensity',
#        'leg_right_pain_intensity', 'working_ability', 'Paidwork'],
#       dtype='object')

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Missing Values

# %%
def checkNaNs(DF):
    """ 
    show only columns with missing values
    """
    print("Total rows in DF:", len(DF))
    print("Total NaNs in DF:", DF.isna().sum().sum())
    all_nans = DF.isna().sum()

    all_nans = all_nans[all_nans > 0].to_frame(name='Missing_Values')
    
    return all_nans
all_nans = checkNaNs(data)
print(all_nans)
import matplotlib.pyplot as plt
import seaborn as sns

# --- 1. Heatmap of Missing Values ---
plt.figure(figsize=(12, 6))
sns.heatmap(data[all_nans.index].isna(), cbar=False, cmap="viridis")
plt.title("Missing Values Heatmap")
plt.show()
# Out:
# Total rows in DF: 1546
# Total NaNs in DF: 4310
#                                   Missing_Values
# Fever                                         34
# Duration_of_pain                              31
# Workoverload                                1087
# Extremely_nervous                             52
# Relationship_with_colleagues                 567
# Irrational_thoughts_risk_lasting              71
# Irrational_thoughts_work                     183
# Coping_strategy                               70
# Kinesiophobia_physical_exercise               51
# Kinesiophobia_pain_stop                       68
# Uses_corticosteroids                          13
# Serious_disease                               12
# Weightloss_per_year                           37
# Loss_muscle_strength                          82
# Trauma                                       680
# Incoordination                               230
# working_ability                             1042

# %%
def remove_columns_nan(DF):
        """  
        Remove the columns where missing value are greater than 10% of total data
        """
        
        print("Columns in current dataset: ", len(DF.columns))    
        columns_to_remove = []
        for col,value in enumerate(pd.isna(DF).sum()):
            if (value/len(data))*100 > 10:
                #print(DF.columns[col])
                columns_to_remove.append(DF.columns[col])
        print("Columns with more than 10% of missing values: ",columns_to_remove)                       
        
        DF= DF.drop(columns=columns_to_remove)
        print("Columns in dataset after removal: ", len(DF.columns))       
        return DF

# %%
def groupbypatients_checkna(DF):
    """
    Remove patients with more than 20% of features missing values (5/6 columns)
    """
    print("Size of dataset before removal:", len(DF))

    #print("Features/",print(6/(37-4) *100)
    # Count NaNs per row (patient-wise)
    DF['Num_NaNs'] = DF.isna().sum(axis=1)

    # Determine threshold dynamically (20% of total columns)
    threshold = int(0.2 * (DF.shape[1] - 1))  # Exclude 'Patient_ID' column from count
    index_patients_nans = DF.loc[DF['Num_NaNs'] >= threshold, 'Patient_ID']

    print(f"Num of patients with NaN >= {threshold}: {len(index_patients_nans)}")

    # Remove patients that exceed the threshold
    DF = DF[~DF['Patient_ID'].isin(index_patients_nans)].drop(columns=['Num_NaNs'])

    print("Size of dataset after removal:", len(DF))
    
    return DF

# %%
def pre_processing(DF):
    """
    MAIN FUNCTION FOR PRE PROCESSING
    """
    data_wo_cols = remove_columns_nan(DF)
    DF = groupbypatients_checkna(data_wo_cols)
    return DF

df = pre_processing(data)
checkNaNs(df)
# Out:
# Columns in current dataset:  38
# Columns with more than 10% of missing values:  ['Workoverload', 'Relationship_with_colleagues', 'Irrational_thoughts_work', 'Trauma', 'Incoordination', 'working_ability']
# Columns in dataset after removal:  32
# Size of dataset before removal: 1546
# Num of patients with NaN >= 6: 19
# Size of dataset after removal: 1527
# Total rows in DF: 1527
# Total NaNs in DF: 404
#                                   Missing_Values
# Fever                                         33
# Duration_of_pain                              13
# Extremely_nervous                             33
# Irrational_thoughts_risk_lasting              52
# Coping_strategy                               51
# Kinesiophobia_physical_exercise               32
# Kinesiophobia_pain_stop                       49
# Uses_corticosteroids                          13
# Serious_disease                               11
# Weightloss_per_year                           36
# Loss_muscle_strength                          81

# %% [markdown]
# # First Data Visualization to understand how to impute the values

# %%
#print(df.dtypes)

# %%
all_nans = checkNaNs(df)
# --- 1. Heatmap of Missing Values ---
plt.figure(figsize=(12, 6))
sns.heatmap(df[all_nans.index].isna(), cbar=False, cmap="viridis")
plt.title("Missing Values Heatmap after preprocessing")
plt.show()

#plot
missing_values_percentage = (all_nans / len(df)) * 100

plt.figure(figsize=(10, 5))
sns.barplot(x=missing_values_percentage.index, y=missing_values_percentage.values.flatten(), palette="magma")
plt.xticks(rotation=45)
plt.ylabel("Percentage of Missing Values")
plt.title("Missing Values Percentage per Feature (Only Columns with NaNs)")
plt.show()
# Out:
# Total rows in DF: 1527
# Total NaNs in DF: 404

# %%
df[all_nans.index].hist(figsize=(12, 10), bins=20, edgecolor="black")
plt.suptitle("Histograms of Features with  missing values", fontsize=16)
plt.show()

# %% [markdown]
# # Data Imputation & Data Mapping

# %%
# Fever = Mean
# duration of pain ???? 
# extr nervous = mean

#  Imputation: K-Nearest Neighbors (KNN) Imputation, Regression Imputation

# per ora ho messo la Moda
df[all_nans.index] = df[all_nans.index].fillna(df[all_nans.index].mean())

# %%
df.columns = df.columns.str.lower()

## removed columns:   ['Workoverload', 'Relationship_with_colleagues', 'Irrational_thoughts_work', 'Trauma', 'Incoordination', 'working_ability']

binary_cols = [
    'fever', 'sick_leave', 'earlier_hospitalization', 'familiy_history',
    'depression', 'stress', 'uses_analgesics', 'uses_corticosteroids', 'serious_disease',
    'neurogenic_signals', 'continuous_pain', 'nocturnal_pain', 'loss_muscle_strength',
    'failure_symptoms', 'paidwork'
]
    
df[binary_cols] = df[binary_cols].astype('bool')

# %%
ordinal_mappings = {
    'duration_of_pain': {
        1: '0-1 weeks', 2: '1-2 weeks', 3: '3-4 weeks', 4: '4-5 weeks',
        5: '6-8 weeks', 6: '9-11 weeks', 7: '3-6 months', 8: '6-9 months',
        9: '9-12 months', 10: 'more than 1 year'
    },
    'weightloss_per_year': {
        1: 'decrease', 2: 'increase', 3: 'stable', 4: 'fluctuating'
    },
    'treatment': {
        1: 'advice', 2: 'rehabilitation', 3: 'surgery', 
        4: 'injection/medication', 5: 'combination of 1-4'
    }
}

for col, mapping in ordinal_mappings.items():
    df[col] = df[col].map(mapping).astype('category')

# %%
numeric_cols = [
    'extremely_nervous', 'irrational_thoughts_risk_lasting',
    'coping_strategy', 'kinesiophobia_physical_exercise',
    'kinesiophobia_pain_stop', 'neck_pain_intensity', 'low_back_pain_intensity',
    'arm_left_pain_intensity', 'arm_right_pain_intensity', 'leg_left_pain_intensity',
    'leg_right_pain_intensity', 'decreased_mobility'
]
df[numeric_cols] = df[numeric_cols].astype(float)

df['age'] = df['age'].astype('category')
print(df.dtypes)
# Out:
# patient_id                             int64
# treatment                           category
# fever                                   bool
# duration_of_pain                    category
# sick_leave                              bool
# earlier_hospitalization                 bool
# familiy_history                         bool
# depression                              bool
# extremely_nervous                    float64
# stress                                  bool
# irrational_thoughts_risk_lasting     float64
# coping_strategy                      float64
# kinesiophobia_physical_exercise      float64
# kinesiophobia_pain_stop              float64
# age                                 category
# uses_analgesics                         bool
# uses_corticosteroids                    bool
# serious_disease                         bool
# neurogenic_signals                      bool
# continuous_pain                         bool
# decreased_mobility                   float64
# nocturnal_pain                          bool
# weightloss_per_year                 category
# loss_muscle_strength                    bool
# failure_symptoms                        bool
# neck_pain_intensity                  float64
# low_back_pain_intensity              float64
# arm_left_pain_intensity              float64
# arm_right_pain_intensity             float64
# leg_left_pain_intensity              float64
# leg_right_pain_intensity             float64
# paidwork                                bool
# dtype: object

# %% [markdown]
# # Data Visualization
# - Corellation Matrix
# - Summary Statistics
# - Distribution of the Outcome Variable
# - Distribution of the Input Variables
# - Outliers
# - Imbalance in the Outcome Variable

# %%
# --- 4. Distribution of Treatment Types ---
plt.figure(figsize=(8, 5))
sns.countplot(x=data["Treatment"], palette="viridis")
plt.title("Distribution of Treatment Types")
plt.xlabel("Treatment Type")
plt.ylabel("Count")
plt.show()

data.describe(include="all")
# Out:
#          Patient_ID    Treatment       Fever  Duration_of_pain   Sick_leave  \
# count   1546.000000  1546.000000  1512.00000       1515.000000  1546.000000
# unique          NaN          NaN         NaN               NaN          NaN
# top             NaN          NaN         NaN               NaN          NaN
# freq            NaN          NaN         NaN               NaN          NaN
# mean     772.500000     2.891979     0.27381          9.193399     0.301423
# std      446.436072     1.867272     0.44606          1.521821     0.459024
# min        0.000000     1.000000     0.00000          1.000000     0.000000
# 25%      386.250000     1.000000     0.00000          9.000000     0.000000
# 50%      772.500000     2.000000     0.00000         10.000000     0.000000
# 75%     1158.750000     5.000000     1.00000         10.000000     1.000000
# max     1545.000000     5.000000     1.00000         10.000000     1.000000
#
#         Earlier_hospitalization  Workoverload  Familiy_history   Depression  \
# count               1546.000000    459.000000      1546.000000  1546.000000
# unique                      NaN           NaN              NaN          NaN
# top                         NaN           NaN              NaN          NaN
# freq                        NaN           NaN              NaN          NaN
# mean                   0.692109      0.400871         0.256792     0.093790
# std                    0.461771      0.490610         0.437005     0.291631
# min                    0.000000      0.000000         0.000000     0.000000
# 25%                    0.000000      0.000000         0.000000     0.000000
# 50%                    1.000000      0.000000         0.000000     0.000000
# 75%                    1.000000      1.000000         1.000000     0.000000
# max                    1.000000      1.000000         1.000000     1.000000
#
#         Extremely_nervous  ...  Failure_symptoms  Incoordination  \
# count         1494.000000  ...       1546.000000     1316.000000
# unique                NaN  ...               NaN             NaN
# top                   NaN  ...               NaN             NaN
# freq                  NaN  ...               NaN             NaN
# mean             3.113119  ...          0.892626        0.386018
# std              3.058689  ...          0.309688        0.487020
# min              0.000000  ...          0.000000        0.000000
# 25%              0.000000  ...          1.000000        0.000000
# 50%              2.000000  ...          1.000000        0.000000
# 75%              6.000000  ...          1.000000        1.000000
# max             10.000000  ...          1.000000        1.000000
#
#         neck_pain_intensity  low_back_pain_intensity  arm_left_pain_intensity  \
# count           1546.000000              1546.000000              1546.000000
# unique                  NaN                      NaN                      NaN
# top                     NaN                      NaN                      NaN
# freq                    NaN                      NaN                      NaN
# mean               1.596378                 6.523933                 0.706339
# std                2.764563                 2.532330                 1.967483
# min                0.000000                 0.000000                 0.000000
# 25%                0.000000                 6.000000                 0.000000
# 50%                0.000000                 7.000000                 0.000000
# 75%                3.000000                 8.000000                 0.000000
# max               10.000000                10.000000                10.000000
#
#         arm_right_pain_intensity  leg_left_pain_intensity  \
# count                1546.000000              1546.000000
# unique                       NaN                      NaN
# top                          NaN                      NaN
# freq                         NaN                      NaN
# mean                    0.716041                 2.805304
# std                     1.996168                 3.454409
# min                     0.000000                 0.000000
# 25%                     0.000000                 0.000000
# 50%                     0.000000                 0.000000
# 75%                     0.000000                 6.000000
# max                    10.000000                10.000000
#
#        leg_right_pain_intensity  working_ability     Paidwork
# count               1546.000000       504.000000  1546.000000
# unique                      NaN              NaN          NaN
# top                         NaN              NaN          NaN
# freq                        NaN              NaN          NaN
# mean                   2.785899         4.696429     0.328590
# std                    3.468595         2.632778     0.469853
# min                    0.000000         0.000000     0.000000
# 25%                    0.000000         3.000000     0.000000
# 50%                    0.000000         5.000000     0.000000
# 75%                    6.000000         7.000000     1.000000
# max                   10.000000        10.000000     1.000000
#
# [11 rows x 38 columns]

# %%
df[numeric_cols].hist(figsize=(10, 9), bins=20, edgecolor="black")
plt.suptitle("Histograms of Continous features", fontsize=16)
plt.show()

plt.figure(figsize=(10, 9))

for i, col in enumerate(numeric_cols, 1):
    plt.subplot(4, 4, i)  # Adjust grid size based on the number of numeric columns
    sns.boxplot(y=df[col])
    plt.title(col)

plt.suptitle("Boxplots of Continuous Features", fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

# %%
corr_matrix = df[numeric_cols].corr()
#print(corr_matrix)
plt.figure(figsize=(10, 5))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
# plt.title("Correlation Matrix")
# plt.show()
# Out:
# <Axes: >

# %% [markdown]
# # Create Databases

# %%
# import numpy as np 
# from sqlalchemy import create_engine 

# import psycopg2

# DB_HOST = DB_HOST
# DB_NAME = DB_NAME
# DB_USER = DB_USER       
# DB_PASS = DB_PASS       
# DB_PORT = DB_PORT               # Default PostgreSQL port

# # SQL queries to create tables
# CREATE_TABLES_SQL = """
#     CREATE TABLE IF NOT EXISTS project.customer (
#         customerid SERIAL PRIMARY KEY,
#         name VARCHAR(100),
#         country VARCHAR(100)
#     );

#     CREATE TABLE IF NOT EXISTS project.product (
#         productid SERIAL PRIMARY KEY,
#         name VARCHAR(100),
#         category VARCHAR(100)
#     );

#     CREATE TABLE IF NOT EXISTS project.sales (
#         orderdate DATE NOT NULL,
#         customerid INTEGER NOT NULL,
#         productid INTEGER NOT NULL,
#         sales DOUBLE PRECISION,
#         PRIMARY KEY (orderdate, customerid, productid)
#     );
# """

# try:
#     # Connect to PostgreSQL
#     conn = psycopg2.connect(
#         dbname=DB_NAME, user=DB_USER, password=DB_PASS, host=DB_HOST, port=DB_PORT
#     )
#     conn.autocommit = True  # Ensure changes are saved automatically

#     # Create a cursor object
#     cursor = conn.cursor()

#     # Execute table creation queries
#     cursor.execute(CREATE_TABLES_SQL)

#     print("Tables created successfully.")

#     # Close the cursor and connection
#     cursor.close()
#     conn.close()

# except Exception as e:
#     print("Error:", e)
    
# #engine = create_engine(f'postgresql://{DB_NAME}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}')
# # product.to_sql('product', engine, schema='ass2', index=False, if_exists='replace')

# %%
# from sqlalchemy import create_engine 

# engine = create_engine(f'postgresql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}')

# product = pd.read_sql('SELECT * FROM ass2.product', engine)
# customers = pd.read_sql('SELECT * FROM ass2.customer', engine)
# sales = pd.read_sql('SELECT * FROM ass2.sales', engine)

# print(product.head())
# print(customers.head())
# print(sales.head())
