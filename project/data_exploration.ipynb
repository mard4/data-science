# %% [markdown]
# ## The dataset
#
# -  1547 real patient cases on low back pain
# - Outcome variable: Treatment 1-5
#
# #### Research question
# 1. To what extend can one, based on the answers given in the questionnaire, automatically determine the
# advised treatment for a patient with back pain.
# 2. To what extend can one reduce the number of questions, i.e. which questions can be left out without
# major decrease in performance? <br>
# Evaluate techniques beyond Decision Trees and Regression.
#
# <h2 style="size:20px;">Input Variables</h2>
# <table style="width: 100%;
#             border-collapse: collapse;">
#     <tr>
#         <th>Variable</th>
#         <th>Description</th>
#     </tr>
#     <tr>
#         <td>Fever</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Duration_in_years</td>
#         <td>
#             1 = 0-1 weeks <br>
#             2 = 1-2 weeks <br>
#             3 = 3-4 weeks <br>
#             4 = 4-5 weeks <br>
#             5 = 6-8 weeks <br>
#             6 = 9-11 weeks <br>
#             7 = 3-6 months <br>
#             8 = 6-9 months <br>
#             9 = 9-12 months <br>
#             10 = more than 1 year
#         </td>
#     </tr>
#     <tr>
#         <td>Sick_leave</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Earlier_hospitalization</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Workoverload</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Familiy_history</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Depression</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Extremely_nervous</td>
#         <td>Value between 0 (not at all) and 10 (Very tense or anxious)</td>
#     </tr>
#     <tr>
#         <td>Stress</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Relationship_with_colleagues</td>
#         <td>Value between 0 (not satisfied at all) and 10 (completely satisfied)</td>
#     </tr>
#     <tr>
#         <td>Irrational_thoughts_risk_lasting</td>
#         <td>Value between 0 (no risk) and 10 (Very high risk)</td>
#     </tr>
#     <tr>
#         <td>Irrational_thoughts_work</td>
#         <td>Value between 0 (fully disagree) and 10 (fully agree)</td>
#     </tr>
#     <tr>
#         <td>Coping_strategy</td>
#         <td>Value between 0 (not at all) and 10 (Can reduce the pain completely)</td>
#     </tr>
#     <tr>
#         <td>Kinesiophobia_physical_exercise</td>
#         <td>Value between 0 (fully disagree) and 10 (fully agree)</td>
#     </tr>
#     <tr>
#         <td>Kinesiophobia_pain_stop</td>
#         <td>Value between 0 (fully disagree) and 10 (fully agree)</td>
#     </tr>
#     <tr>
#         <td>Age</td>
#         <td>0-19, 20-29, ….., >=80</td>
#     </tr>
#     <tr>
#         <td>Uses_analgesics</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Uses_corticosteroids</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Serious_disease</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Neurogenic_signals</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Continuous_pain</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Decreased_mobility</td>
#         <td>Value</td>
#     </tr>
#     <tr>
#         <td>Nocturnal_pain</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Weightloss_per_year</td>
#         <td>1=decrease, 2=increase, 3=stable, 4=fluctuating</td>
#     </tr>
#     <tr>
#         <td>Loss_muscle_strength</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Trauma</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Failure_symptoms</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Incoordination</td>
#         <td>1=yes, 0=no</td>
#     </tr>
#     <tr>
#         <td>Neck_pain_intensity</td>
#         <td>Value between 0 (None) and 10 (Unbearable)</td>
#     </tr>
#     <tr>
#         <td>Low_back_pain_intensity</td>
#         <td>Value between 0 (None) and 10 (Unbearable)</td>
#     </tr>
#     <tr>
#         <td>Arm_left_pain_intensity</td>
#         <td>Value between 0 (None) and 10 (Unbearable)</td>
#     </tr>
#     <tr>
#         <td>Arm_right_pain_intensity</td>
#         <td>Value between 0 (None) and 10 (Unbearable)</td>
#     </tr>
#     <tr>
#         <td>Leg_left_pain_intensity</td>
#         <td>Value between 0 (None) and 10 (Unbearable)</td>
#     </tr>
#     <tr>
#         <td>Leg_right_pain_intensity</td>
#         <td>Value between 0 (None) and 10 (Unbearable)</td>
#     </tr>
#     <tr>
#         <td>Working_ability</td>
#         <td>Value between 0 and 10</td>
#     </tr>
#     <tr>
#         <td>Paid_work</td>
#         <td>1=yes, 0=no</td>
#     </tr>
# </table>
#
# <h2>Outcome Variable</h2>
# <table>
#     <tr>
#         <th>Variable</th>
#         <th>Description</th>
#     </tr>
#     <tr>
#         <td>Treatment</td>
#         <td>
#             1. Advice <br>
#             2. Rehabilitation <br>
#             3. Surgery <br>
#             4. Injection/medication <br>
#             5. Combination of 1-4
#         </td>
#     </tr>
# </table>

# %% [markdown]
# To use the database, connect to bronto.ewi.utwente.nl using these credentials:
#
# - Example command for connecting:
# psql -h bronto.ewi.utwente.nl -U dab_ds2425-2a_10 dab_ds2425-2a_10
#
# - https://bronto.ewi.utwente.nl/phppgadmin/

# %%
import pandas as pd
from connection import *
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

print("Columns in dataset")
data = pd.read_excel("./data/Dataset - LBP RA.xlsx", sheet_name='Training Dataset')
print(data.columns)
##print(training_dataset.head())

# Create the Patient ID column
data.insert(0, 'clinical_id', data.index)
data.insert(0, 'psychological_id', data.index)
data.insert(0, 'pain_id', data.index)
data.insert(0, 'work_id', data.index)
data.insert(0, 'Patient_ID', data.index)

data.head(10)
# %matplotlib inline
# Out:
# Columns in dataset
# Index(['Treatment', 'Fever', 'Duration_of_pain', 'Sick_leave',
#        'Earlier_hospitalization', 'Workoverload', 'Familiy_history',
#        'Depression', 'Extremely_nervous', 'Stress',
#        'Relationship_with_colleagues', 'Irrational_thoughts_risk_lasting',
#        'Irrational_thoughts_work', 'Coping_strategy',
#        'Kinesiophobia_physical_exercise', 'Kinesiophobia_pain_stop', 'Age',
#        'Uses_analgesics', 'Uses_corticosteroids', 'Serious_disease',
#        'Neurogenic_signals', 'Continuous_pain', 'Decreased_mobility',
#        'Nocturnal_pain', 'Weightloss_per_year', 'Loss_muscle_strength',
#        'Trauma', 'Failure_symptoms', 'Incoordination', 'neck_pain_intensity',
#        'low_back_pain_intensity', 'arm_left_pain_intensity',
#        'arm_right_pain_intensity', 'leg_left_pain_intensity',
#        'leg_right_pain_intensity', 'working_ability', 'Paidwork'],
#       dtype='object')

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Missing Values

# %%
def checkNaNs(DF):
    """ 
    show only columns with missing values
    """
    print("Total rows in DF:", len(DF))
    print("Total NaNs in DF:", DF.isna().sum().sum())
    all_nans = DF.isna().sum()

    all_nans = all_nans[all_nans > 0].to_frame(name='Missing_Values')
    
    return all_nans

def plotNaNs(DF):
    """ 
    Plot missing values heatmap
    """
    plt.figure(figsize=(12, 6))
    sns.heatmap(DF[checkNaNs(DF).index].isna(), cbar=False, cmap="viridis")
    plt.title("Missing Values Heatmap")
    plt.show()

all_nans = checkNaNs(data)
print(all_nans)
plotNaNs(data)
# Out:
# Total rows in DF: 1546
# Total NaNs in DF: 4310
#                                   Missing_Values
# Fever                                         34
# Duration_of_pain                              31
# Workoverload                                1087
# Extremely_nervous                             52
# Relationship_with_colleagues                 567
# Irrational_thoughts_risk_lasting              71
# Irrational_thoughts_work                     183
# Coping_strategy                               70
# Kinesiophobia_physical_exercise               51
# Kinesiophobia_pain_stop                       68
# Uses_corticosteroids                          13
# Serious_disease                               12
# Weightloss_per_year                           37
# Loss_muscle_strength                          82
# Trauma                                       680
# Incoordination                               230
# working_ability                             1042
# Total rows in DF: 1546
# ...

# %%
def remove_columns_nan(DF):
        """  
        Remove the columns where missing value are greater than 10% of total data
        """
        
        print("Columns in current dataset: ", len(DF.columns))    
        columns_to_remove = []
        for col,value in enumerate(pd.isna(DF).sum()):
            if (value/len(data))*100 > 10:
                #print(DF.columns[col])
                columns_to_remove.append(DF.columns[col])
        print("Columns with more than 10% of missing values: ",columns_to_remove)                       
        
        DF= DF.drop(columns=columns_to_remove)
        print("Columns in dataset after removal: ", len(DF.columns))       
        return DF

# %%
def groupbypatients_checkna(DF):
    """
    Remove patients with more than 20% of features missing values (5/6 columns)
    """
    print("Size of dataset before removal:", len(DF))

    #print("Features/",print(6/(37-4) *100)
    # Count NaNs per row (patient-wise)
    DF['Num_NaNs'] = DF.isna().sum(axis=1)

    # Determine threshold dynamically (20% of total columns)
    threshold = int(0.2 * (DF.shape[1] - 1))  # Exclude 'Patient_ID' column from count
    index_patients_nans = DF.loc[DF['Num_NaNs'] >= threshold, 'Patient_ID']

    print(f"Num of patients with NaN >= {threshold}: {len(index_patients_nans)}")

    # Remove patients that exceed the threshold
    DF = DF[~DF['Patient_ID'].isin(index_patients_nans)].drop(columns=['Num_NaNs'])

    print("Size of dataset after removal:", len(DF))
    
    return DF

# %%
def pre_processing(DF):
    """
    MAIN FUNCTION FOR PRE PROCESSING
    """
    data_wo_cols = remove_columns_nan(DF)
    DF = groupbypatients_checkna(data_wo_cols)
    return DF

df = pre_processing(data)
checkNaNs(df)
# Out:
# Columns in current dataset:  42
# Columns with more than 10% of missing values:  ['Workoverload', 'Relationship_with_colleagues', 'Irrational_thoughts_work', 'Trauma', 'Incoordination', 'working_ability']
# Columns in dataset after removal:  36
# Size of dataset before removal: 1546
# Num of patients with NaN >= 7: 3
# Size of dataset after removal: 1543
# Total rows in DF: 1543
# Total NaNs in DF: 500
#                                   Missing_Values
# Fever                                         33
# Duration_of_pain                              28
# Extremely_nervous                             49
# Irrational_thoughts_risk_lasting              68
# Coping_strategy                               67
# Kinesiophobia_physical_exercise               48
# Kinesiophobia_pain_stop                       65
# Uses_corticosteroids                          13
# Serious_disease                               12
# Weightloss_per_year                           36
# ...

# %% [markdown]
# # First Data Visualization to understand how to impute the values

# %%
print("NaNs after pre-processing")
all_nans = checkNaNs(df)
#plotNaNs(df)
#plot
missing_values_percentage = (all_nans / len(df)) * 100

plt.figure(figsize=(8, 5))
sns.barplot(x=missing_values_percentage.index, y=missing_values_percentage.values.flatten(), palette="magma")
plt.xticks(rotation=45)
plt.ylabel("Percentage of Missing Values")
plt.title("Missing Values Percentage per Feature (Only Columns with NaNs)")
plt.show()
# Out:
# NaNs after pre-processing
# Total rows in DF: 1543
# Total NaNs in DF: 500

# %%
df[all_nans.index].hist(figsize=(12, 10), bins=20, edgecolor="black")
plt.suptitle("Histograms of Features with  missing values", fontsize=16)
plt.show()

# %% [markdown]
# # Data Mapping

# %%
df.columns = df.columns.str.lower()

# %% [markdown]
# # Data Visualization
# - Corellation Matrix
# - Summary Statistics
# - Distribution of the Outcome Variable
# - Distribution of the Input Variables
# - Outliers
# - Imbalance in the Outcome Variable

# %%
# --- 4. Distribution of Treatment Types ---
plt.figure(figsize=(8, 5))
sns.countplot(x=data["Treatment"], palette="viridis")
plt.title("Distribution of Treatment Types")
plt.xlabel("Treatment Type")
plt.ylabel("Count")
plt.show()

data.describe(include="all")
# Out:
#          Patient_ID      work_id      pain_id  psychological_id  clinical_id  \
# count   1546.000000  1546.000000  1546.000000       1546.000000  1546.000000
# unique          NaN          NaN          NaN               NaN          NaN
# top             NaN          NaN          NaN               NaN          NaN
# freq            NaN          NaN          NaN               NaN          NaN
# mean     772.500000   772.500000   772.500000        772.500000   772.500000
# std      446.436072   446.436072   446.436072        446.436072   446.436072
# min        0.000000     0.000000     0.000000          0.000000     0.000000
# 25%      386.250000   386.250000   386.250000        386.250000   386.250000
# 50%      772.500000   772.500000   772.500000        772.500000   772.500000
# 75%     1158.750000  1158.750000  1158.750000       1158.750000  1158.750000
# max     1545.000000  1545.000000  1545.000000       1545.000000  1545.000000
#
# ...

# %% [markdown]
# # Create Databases

# %%
# Convert entire DataFrame to object dtype if you have mixed types
df = df.astype(object)

# Replace NaNs with None (PostgreSQL interprets None as NULL)
df = df.where(pd.notnull(df), None)
df.fever.value_counts(dropna=False)
# Out:
# fever
# 0.0     1097
# 1.0      413
# None      33
# Name: count, dtype: int64

# %%
# create columns
df_new = df.copy()
dict_mapping = {'1': 'Advice', '2': 'Rehabilitation', '3': 'Surgery', '4': 'Injection/Medication', '5': 'Combination_of_1_4'}
df_new['treatment_description'] = df_new.apply(lambda x: dict_mapping[str(x['treatment'])], axis=1) 
df_new.rename(columns={'familiy_history': 'family_history'}, inplace=True)

# %%
df_new.columns

# conversione
def convert_toBoolean(DF, boolean_columns):
    for col in boolean_columns:
        DF[col] = DF[col].map({'yes': True, 'no': False, '1': True, '0': False, True: True, False: False, np.nan: np.nan})
        DF[col] = DF[col].astype('boolean')
    return DF

def convert_toInt(DF, integer_columns):
    for col in integer_columns:
        DF[col] = pd.to_numeric(DF[col], errors='coerce')
        DF[col] = DF[col].astype('Int32')
    return DF

boolean_columns = [
    'family_history',
    'serious_disease',
    'fever',
    'uses_analgesics',
    'uses_corticosteroids',
    'neurogenic_signals',
    'loss_muscle_strength',
    'failure_symptoms',
    'depression',
    'stress',
    'sick_leave',
    'earlier_hospitalization',
    'paidwork'
]

integer_columns =  [
    'decreased_mobility',
    'weightloss_per_year',
    'extremely_nervous',
    'irrational_thoughts_risk_lasting',
    'coping_strategy',
    'kinesiophobia_physical_exercise',
    'kinesiophobia_pain_stop',
    'nocturnal_pain',
    'continuous_pain',
    'duration_of_pain',
    'neck_pain_intensity',
    'low_back_pain_intensity',
    'arm_left_pain_intensity',
    'arm_right_pain_intensity',
    'leg_left_pain_intensity',
    'leg_right_pain_intensity'
]


df_new = convert_toBoolean(df_new, boolean_columns)
df_new = convert_toInt(df_new, integer_columns)
df_new.dtypes
# Out:
# patient_id                           object
# work_id                              object
# pain_id                              object
# psychological_id                     object
# clinical_id                          object
# treatment                            object
# fever                               boolean
# duration_of_pain                      Int32
# sick_leave                          boolean
# earlier_hospitalization             boolean
# family_history                      boolean
# depression                          boolean
# extremely_nervous                     Int32
# stress                              boolean
# irrational_thoughts_risk_lasting      Int32
# coping_strategy                       Int32
# kinesiophobia_physical_exercise       Int32
# kinesiophobia_pain_stop               Int32
# age                                  object
# uses_analgesics                     boolean
# uses_corticosteroids                boolean
# ...

# %%
from connection import * 
import numpy as np
from sqlalchemy import create_engine 
import psycopg2

DB_HOST = DB_HOST
DB_NAME = DB_NAME
DB_USER = DB_USER       
DB_PASS = DB_PASS       
DB_PORT = DB_PORT               # Default PostgreSQL port

CREATE_tables_sql = """
                    CREATE TABLE IF NOT EXISTS project.patient (
                   
                        patient_id SERIAL PRIMARY KEY,
                        age VARCHAR(50),
                        family_history BOOLEAN,
                        serious_disease BOOLEAN
                    );
                    
                    CREATE TABLE IF NOT EXISTS project.radvice (
                            treatment SERIAL PRIMARY KEY,
                            treatment_description VARCHAR(50),
                            patient_id INTEGER REFERENCES project.patient(patient_id),
                            clinical_id INTEGER REFERENCES project.clinical(clinical_id),
                            psychological_id INTEGER REFERENCES project.psychological(psychological_id),
                            pain_id INTEGER REFERENCES project.pain(pain_id),
                            work_id INTEGER REFERENCES project.work(work_id)
                    );

                    CREATE TABLE IF NOT EXISTS project.clinical (
                        clinical_id SERIAL PRIMARY KEY,
                        fever BOOLEAN,
                        uses_analgesics BOOLEAN,
                        uses_corticosteroids BOOLEAN,
                        neurogenic_signals BOOLEAN,
                        decreased_mobility INTEGER,
                        weightloss_per_year INTEGER,
                        loss_muscle_strength BOOLEAN,
                        failure_symptoms BOOLEAN
                    );
                    
                    CREATE TABLE IF NOT EXISTS project.psychological (
                        psychological_id SERIAL PRIMARY KEY,
                        depression BOOLEAN,
                        extremely_nervous INTEGER,
                        stress BOOLEAN,
                        irrational_thoughts_risk_lasting INTEGER,
                        coping_strategy INTEGER,
                        kinesiophobia_physical_exercise INTEGER
                    );
                    
                    CREATE TABLE IF NOT EXISTS project.work (
                        work_id SERIAL PRIMARY KEY,
                        sick_leave BOOLEAN,
                        earlier_hospitalization BOOLEAN,
                        paidwork BOOLEAN
                    );
                    
                    CREATE TABLE IF NOT EXISTS project.pain (
                        pain_id SERIAL PRIMARY KEY,
                        kinesiophobia_pain_stop INTEGER,
                        nocturnal_pain INTEGER,
                        continuous_pain INTEGER,
                        duration_of_pain INTEGER,
                        neck_pain_intensity INTEGER,
                        low_back_pain_intensity INTEGER,
                        arm_left_pain_intensity INTEGER,
                        arm_right_pain_intensity INTEGER,
                        leg_left_pain_intensity INTEGER,
                        leg_right_pain_intensity INTEGER
                    );
                    
       """

# %%
##### Connecting
try:
    # Connect to PostgreSQL
    conn = psycopg2.connect(
        dbname=DB_NAME, user=DB_USER, password=DB_PASS, host=DB_HOST, port=DB_PORT
    )
    conn.autocommit = True  # Ensure changes are saved automatically

    # Create a cursor object
    cursor = conn.cursor()

    # Execute table creation queries
    cursor.execute(CREATE_tables_sql)

    print("Tables created successfully.")

    # Close the cursor and connection
    cursor.close()
    conn.close()

except Exception as e:
    print("Error:", e)
    
engine = create_engine(f'postgresql://{DB_NAME}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}')

# Create the tables in the database

# patient
df_new[['patient_id', 'age', 'family_history', 'serious_disease']]\
    .to_sql('patient', engine, schema='project', index=False, if_exists='replace')

# clinical
df_new[['clinical_id', 'fever', 'uses_analgesics', 'uses_corticosteroids',
        'neurogenic_signals', 'decreased_mobility', 'weightloss_per_year',
        'loss_muscle_strength', 'failure_symptoms']]\
    .to_sql('clinical', engine, schema='project', index=False, if_exists='replace')

# psychological
df_new[['psychological_id', 'depression', 'extremely_nervous', 'stress',
        'irrational_thoughts_risk_lasting', 'coping_strategy',
        'kinesiophobia_physical_exercise']]\
    .to_sql('psychological', engine, schema='project', index=False, if_exists='replace')

# work
df_new[['work_id', 'sick_leave', 'earlier_hospitalization', 'paidwork']]\
    .to_sql('work', engine, schema='project', index=False, if_exists='replace')

# pain
df_new[['pain_id', 'kinesiophobia_pain_stop', 'nocturnal_pain', 'continuous_pain',
        'duration_of_pain', 'neck_pain_intensity', 'low_back_pain_intensity',
        'arm_left_pain_intensity', 'arm_right_pain_intensity',
        'leg_left_pain_intensity', 'leg_right_pain_intensity']]\
    .to_sql('pain', engine, schema='project', index=False, if_exists='replace')

# radvice
df_new[['treatment','treatment_description', 'patient_id', 'clinical_id', 'psychological_id',
        'pain_id', 'work_id']]\
    .to_sql('radvice', engine, schema='project', index=False, if_exists='replace')
# Out:
# Tables created successfully.
# 543
